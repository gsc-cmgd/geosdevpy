# %% [markdown]
# # Create interactive maps
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gsc-cmgd/geosdevpy/blob/main/docs/examples/map.ipynb)

# %%
import geosdevpy

# %%
from geosdevpy.common import hello_world

# %%
hello_world()
# Out:
# Hello World!
